# %% [markdown]
# Author : A.B.M. Rokon-uz-zaman Roman

# %%
# !pip install ultralytics==8.0.11
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.6/258.6 KB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 KB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 39.8 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=a220ae1b365997cc32257874d5406ce8684e95078747187723d21d566086de9b
# ...

# %%
import ultralytics
from ultralytics import YOLO

# %%
# !pwd
# Out:
# /content

# %%
# !mkdir datasets

# %%
# %cd datasets
# Out:
# /content/datasets

# %%
# !pwd
# Out:
# /content/datasets

# %% [markdown]
# dataset https://universe.roboflow.com/wpns/weapons-s4k8n/dataset/1
#
# class : knife , pistol
#
#
# 6092  images

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tBosVd9VJDCWjWwJpugD")
project = rf.workspace("wpns").project("weapons-s4k8n")
dataset = project.version(1).download("yolov5")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 KB 5.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 KB 22.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 9.5 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=1e22bbc1201c964a8cea0d2780b8374ef2877612a0f980486b2f2efe65b33885
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/datasets/weapons-1/data.yaml epochs=35 imgsz=800
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 22.1MB/s]
#
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Now display confusion matrix

# %%
img = cv2.imread('/content/runs/detect/train/confusion_matrix.png', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-cd6cb03afb78> in <module>
# ----> 1 img = cv2.imread('/content/runs/detect/train/confusion_matrix.png', cv2.IMREAD_UNCHANGED)
#       2 cv2_imshow(img)
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# validation

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:17<00:00,  4.48it/s]
#                    all       1261       1350      0.908      0.836      0.914      0.607
#                  knife       1261        706      0.898        0.8      0.889      0.501
#                 pistol       1261        644      0.918      0.872      0.939      0.713
# Speed: 0.5ms pre-process, 3.9ms inference, 0.0ms loss, 1.6ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.1 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:17<00:00,  4.56it/s]
#                    all       1261       1350      0.908      0.836      0.917      0.639
#                  knife       1261        706      0.898        0.8      0.895      0.533
#                 pistol       1261        644      0.918      0.872       0.94      0.746
# Speed: 0.5ms pre-process, 3.8ms inference, 0.0ms loss, 1.6ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.2 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:17<00:00,  4.57it/s]
#                    all       1261       1350      0.908      0.836      0.913      0.644
#                  knife       1261        706      0.898        0.8       0.89      0.539
#                 pistol       1261        644      0.918      0.872      0.937      0.748
# Speed: 0.5ms pre-process, 3.9ms inference, 0.0ms loss, 1.6ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.5 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:17<00:00,  4.58it/s]
#                    all       1261       1350      0.933      0.806      0.886      0.641
#                  knife       1261        706      0.924      0.755      0.855      0.538
#                 pistol       1261        644      0.942      0.857      0.917      0.744
# Speed: 0.5ms pre-process, 4.0ms inference, 0.0ms loss, 1.6ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.8 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:15<00:00,  5.24it/s]
#                    all       1261       1350      0.992      0.416      0.705      0.575
#                  knife       1261        706       0.99      0.293      0.642      0.471
#                 pistol       1261        644      0.994      0.539      0.767      0.679
# Speed: 0.6ms pre-process, 4.1ms inference, 0.0ms loss, 1.2ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.3 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:17<00:00,  4.61it/s]
#                    all       1261       1350      0.908      0.836      0.908      0.645
#                  knife       1261        706      0.898        0.8      0.887      0.543
#                 pistol       1261        644      0.918      0.872       0.93      0.748
# Speed: 0.5ms pre-process, 3.9ms inference, 0.0ms loss, 1.6ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.25 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:17<00:00,  4.45it/s]
#                    all       1261       1350      0.908      0.836      0.912      0.645
#                  knife       1261        706      0.898        0.8       0.89      0.541
#                 pistol       1261        644      0.918      0.872      0.935      0.749
# Speed: 0.5ms pre-process, 4.0ms inference, 0.0ms loss, 1.8ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.9 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:12<00:00,  6.55it/s]
#                    all       1261       1350      0.997      0.176      0.587      0.522
#                  knife       1261        706          1     0.0595       0.53      0.432
#                 pistol       1261        644      0.995      0.292      0.644      0.612
# Speed: 0.7ms pre-process, 4.3ms inference, 0.0ms loss, 0.7ms post-process per image

# %% [markdown]
# inference

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/datasets/weapons-1/test/images
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# image 1/626 /content/datasets/weapons-1/test/images/DSC_0008_jpg.rf.8880c5819670743d39e2390724e9b768.jpg: 640x640 1 knife, 9.9ms
# image 2/626 /content/datasets/weapons-1/test/images/DSC_0013_jpg.rf.e5d5d4b1ccae78f8c109f5bf250e5bfb.jpg: 640x640 1 knife, 10.2ms
# image 3/626 /content/datasets/weapons-1/test/images/DSC_00211_jpg.rf.1b6b8d731acaf1272c1fe43d06fee27d.jpg: 640x640 2 knifes, 10.2ms
# image 4/626 /content/datasets/weapons-1/test/images/DSC_00221_jpg.rf.d49b2946136f29971cc694ea6f54b7f3.jpg: 640x640 1 knife, 10.3ms
# image 5/626 /content/datasets/weapons-1/test/images/DSC_00481_jpg.rf.9d4382b0b6982e6bec6daaa94f91f660.jpg: 640x640 10.2ms
# image 6/626 /content/datasets/weapons-1/test/images/DSC_0048_jpg.rf.f5363c1a8c28a7d2a129d2cbaa7ee599.jpg: 640x640 1 knife, 11.2ms
# ...

# %%
# !zip -r /content/yolov8n__pisknf_ac_91_ep35tvt2.zip /content/runs/
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/val/ (stored 0%)
#   adding: content/runs/detect/val/confusion_matrix.png (deflated 36%)
#   adding: content/runs/detect/val/R_curve.png (deflated 12%)
#   adding: content/runs/detect/val/val_batch1_labels.jpg (deflated 12%)
#   adding: content/runs/detect/val/val_batch0_labels.jpg (deflated 14%)
#   adding: content/runs/detect/val/val_batch2_labels.jpg (deflated 13%)
#   adding: content/runs/detect/val/val_batch2_pred.jpg (deflated 13%)
#   adding: content/runs/detect/val/F1_curve.png (deflated 11%)
#   adding: content/runs/detect/val/PR_curve.png (deflated 15%)
#   adding: content/runs/detect/val/val_batch1_pred.jpg (deflated 12%)
#   adding: content/runs/detect/val/val_batch0_pred.jpg (deflated 14%)
#   adding: content/runs/detect/val/P_curve.png (deflated 14%)
#   adding: content/runs/detect/val22/ (stored 0%)
# ...

# %%
from google.colab import files

files.download('/content/yolov8n__pisknf_ac_91_ep35tvt2.zip')

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread('/content/runs/detect/val/val_batch1_pred.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

# %%
import cv2
img = cv2.imread('/content/runs/detect/val/val_batch1_labels.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.4 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:16<00:00,  4.68it/s]
#                    all       1261       1350      0.904       0.84      0.899      0.644
#                  knife       1261        706      0.892      0.805      0.874      0.542
#                 pistol       1261        644      0.916      0.876      0.923      0.747
# Speed: 0.4ms pre-process, 3.9ms inference, 0.0ms loss, 1.5ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.6 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:18<00:00,  4.37it/s]
#                    all       1261       1350      0.958      0.741      0.858      0.633
#                  knife       1261        706      0.952       0.67      0.819      0.529
#                 pistol       1261        644      0.965      0.812      0.897      0.737
# Speed: 1.0ms pre-process, 4.0ms inference, 0.0ms loss, 1.9ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.7 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:15<00:00,  5.09it/s]
#                    all       1261       1350      0.979      0.627      0.806      0.618
#                  knife       1261        706      0.982      0.531      0.758      0.516
#                 pistol       1261        644      0.977      0.722      0.854       0.72
# Speed: 0.6ms pre-process, 4.0ms inference, 0.0ms loss, 1.5ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.5 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:16<00:00,  4.67it/s]
#                    all       1261       1350      0.933      0.806      0.886      0.641
#                  knife       1261        706      0.924      0.755      0.855      0.538
#                 pistol       1261        644      0.942      0.857      0.917      0.744
# Speed: 0.6ms pre-process, 4.0ms inference, 0.0ms loss, 1.5ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=1 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:11<00:00,  7.18it/s]
#                    all       1261       1350          0          0          0          0
# Speed: 1.1ms pre-process, 4.3ms inference, 0.0ms loss, 0.3ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.1 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:18<00:00,  4.25it/s]
#                    all       1261       1350      0.908      0.836      0.917      0.639
#                  knife       1261        706      0.898        0.8      0.895      0.533
#                 pistol       1261        644      0.918      0.872       0.94      0.746
# Speed: 0.7ms pre-process, 3.8ms inference, 0.0ms loss, 1.7ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.001 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:17<00:00,  4.48it/s]
#                    all       1261       1350      0.908      0.836      0.914      0.607
#                  knife       1261        706      0.898        0.8      0.889      0.501
#                 pistol       1261        644      0.918      0.872      0.939      0.713
# Speed: 0.4ms pre-process, 4.0ms inference, 0.0ms loss, 1.6ms post-process per image

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt conf=0.01 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:17<00:00,  4.45it/s]
#                    all       1261       1350      0.908      0.836      0.915      0.621
#                  knife       1261        706      0.898        0.8       0.89      0.511
#                 pistol       1261        644      0.918      0.872       0.94       0.73
# Speed: 0.6ms pre-process, 4.0ms inference, 0.0ms loss, 1.6ms post-process per image

# %%
img = cv2.imread('/content/runs/detect/train/train_batch18600.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-7ff2a8711ef2> in <module>
#       1 img = cv2.imread('/content/runs/detect/train/train_batch18600.jpg', cv2.IMREAD_UNCHANGED)
# ----> 2 cv2_imshow(img)
#
# /usr/local/lib/python3.9/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img = cv2.imread('/content/runs/detect/train/train_batch18601.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-560771671812> in <module>
#       1 img = cv2.imread('/content/runs/detect/train/train_batch18601.jpg', cv2.IMREAD_UNCHANGED)
# ----> 2 cv2_imshow(img)
#
# /usr/local/lib/python3.9/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img = cv2.imread('/content/runs/detect/train/val_batch2_pred.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

# %%
img = cv2.imread('/content/runs/detect/train/val_batch2_labels.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/weapons-1/valid/labels.cache... 1261 images, 0 backgrounds, 0 corrupt: 100% 1261/1261 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 79/79 [00:19<00:00,  4.12it/s]
#                    all       1261       1350      0.908      0.836      0.914      0.607
#                  knife       1261        706      0.898        0.8      0.889      0.501
#                 pistol       1261        644      0.918      0.872      0.939      0.713
# Speed: 0.5ms pre-process, 4.0ms inference, 0.0ms loss, 1.8ms post-process per image

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.01 data=/content/datasets/weapons-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.11 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing...
# Model summary: 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# ...
# 100% 476k/476k [00:00<00:00, 87.1MB/s]
# image 1/1 /content/bus.jpg: 640x480 3 knifes, 14 pistols, 16.8ms
# Speed: 0.6ms pre-process, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3

# %%
# !yolo task=detect mode=test model=/content/runs/detect/train/weights/best.pt conf=0.01 data=/content/datasets/weapons-1/data.yaml
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/cli.py", line 148, in entrypoint
#     cli(cfg)
#   File "/usr/local/lib/python3.9/dist-packages/ultralytics/yolo/cli.py", line 82, in cli
#     raise SyntaxError(f"yolo mode={mode} is invalid. Valid modes are: {', '.join(modes.keys())}\n{CLI_HELP_MSG}")
# SyntaxError: yolo mode=test is invalid. Valid modes are: train, val, predict, export
#
#     YOLOv8 CLI Usage examples:
#
#     1. Install the ultralytics package:
#
#         pip install ultralytics
#
#     2. Train, Val, Predict and Export using 'yolo' commands:
#
#             yolo TASK MODE ARGS
#
#             Where   TASK (optional) is one of [detect, segment, classify]
#                     MODE (required) is one of [train, val, predict, export]
# ...

# %%
# !yolo task=detect mode=export model=/content/runs/detect/train/weights/best.pt conf=0.01 data=/content/datasets/weapons-1/data.yaml
# Out:
# {'task': 'detect', 'mode': 'export', 'model': '/content/runs/detect/train/weights/best.pt', 'data': '/content/datasets/weapons-1/data.yaml', 'epochs': 100, 'patience': 50, 'batch': 16, 'imgsz': 640, 'save': True, 'cache': False, 'device': None, 'workers': 8, 'project': None, 'name': None, 'exist_ok': False, 'pretrained': False, 'optimizer': 'SGD', 'verbose': False, 'seed': 0, 'deterministic': True, 'single_cls': False, 'image_weights': False, 'rect': False, 'cos_lr': False, 'close_mosaic': 10, 'resume': False, 'overlap_mask': True, 'mask_ratio': 4, 'dropout': 0.0, 'val': True, 'save_json': False, 'save_hybrid': False, 'conf': 0.01, 'iou': 0.7, 'max_det': 300, 'half': False, 'dnn': False, 'plots': True, 'source': None, 'show': False, 'save_txt': False, 'save_conf': False, 'save_crop': False, 'hide_labels': False, 'hide_conf': False, 'vid_stride': 1, 'line_thickness': 3, 'visualize': False, 'augment': False, 'agnostic_nms': False, 'retina_masks': False, 'format': 'torchscript', 'keras'
# ...

# %%
# !yolo task=detect mode=export model=/content/runs/detect/train/weights/best.pt data=/content/datasets/weapons-1/data.yaml
# Out:
# {'task': 'detect', 'mode': 'export', 'model': '/content/runs/detect/train/weights/best.pt', 'data': '/content/datasets/weapons-1/data.yaml', 'epochs': 100, 'patience': 50, 'batch': 16, 'imgsz': 640, 'save': True, 'cache': False, 'device': None, 'workers': 8, 'project': None, 'name': None, 'exist_ok': False, 'pretrained': False, 'optimizer': 'SGD', 'verbose': False, 'seed': 0, 'deterministic': True, 'single_cls': False, 'image_weights': False, 'rect': False, 'cos_lr': False, 'close_mosaic': 10, 'resume': False, 'overlap_mask': True, 'mask_ratio': 4, 'dropout': 0.0, 'val': True, 'save_json': False, 'save_hybrid': False, 'conf': None, 'iou': 0.7, 'max_det': 300, 'half': False, 'dnn': False, 'plots': True, 'source': None, 'show': False, 'save_txt': False, 'save_conf': False, 'save_crop': False, 'hide_labels': False, 'hide_conf': False, 'vid_stride': 1, 'line_thickness': 3, 'visualize': False, 'augment': False, 'agnostic_nms': False, 'retina_masks': False, 'format': 'torchscript', 'keras'
# ...
